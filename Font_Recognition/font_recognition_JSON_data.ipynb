# %% [markdown]
# # Get the data

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Import

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

import os
from pathlib import Path
import cv2

# %%
test_path = Path('/content/gdrive/MyDrive/Machima/font_recognition/test')
print(str(test_path))
# Out:
# /content/gdrive/MyDrive/Machima/font_recognition/test

# %%
test_path = '/content/gdrive/MyDrive/Machima/font_recognition/test'
test_file = sorted(os.listdir(test_path))

# %%
test_file[:5]
# Out:
# ['1001', '1002', '1003', '1004', '1005']

# %%
df_test = pd.DataFrame(data=test_file, columns=['file_name'])
df_test['path'] = df_test.apply(lambda x:str(test_path)+"/"+x)
df_test
# Out:
#     file_name                                               path
# 0        1001  /content/gdrive/MyDrive/Machima/font_recogniti...
# 1        1002  /content/gdrive/MyDrive/Machima/font_recogniti...
# 2        1003  /content/gdrive/MyDrive/Machima/font_recogniti...
# 3        1004  /content/gdrive/MyDrive/Machima/font_recogniti...
# 4        1005  /content/gdrive/MyDrive/Machima/font_recogniti...
# ..        ...                                                ...
# 995      1996  /content/gdrive/MyDrive/Machima/font_recogniti...
# 996      1997  /content/gdrive/MyDrive/Machima/font_recogniti...
# 997      1998  /content/gdrive/MyDrive/Machima/font_recogniti...
# 998      1999  /content/gdrive/MyDrive/Machima/font_recogniti...
# 999      2000  /content/gdrive/MyDrive/Machima/font_recogniti...
#
# [1000 rows x 2 columns]

# %% [markdown]
# # Get file path of images and json files

# %%
df_test.loc[:, 'path'].values

# %%
images_path = []
jsons_path = []

for i in df_test.loc[:, 'path'].values:
    file_path = os.listdir(i)
    
    json_path = i + "/" + file_path[1]
    img_path = i + "/" + file_path[0]
    
    jsons_path.append(json_path)
    images_path.append(img_path)

# %%
def display_image_in_actual_size(im_path):
    dpi = 80
    im_data = plt.imread(im_path)
    height, width, depth = im_data.shape

    # What size does the figure need to be in inches to fit the image?
    figsize = width / float(dpi), height / float(dpi)

    # Create a figure of the right size with one axes that takes up the full figure
    fig = plt.figure(figsize=figsize)
    ax = fig.add_axes([0, 0, 1, 1])

    # Hide spines, ticks, etc.
    ax.axis('off')

    # Display the image.
    ax.imshow(im_data, cmap='gray')

    plt.show()

display_image_in_actual_size(images_path[0])

# %% [markdown]
# # Read json file

# %%
json_data[0]
# Out:
# [{'height': 29.31300115585327,
#   'id': 'b68ab614',
#   'width': 287.1453744471073,
#   'x': 88.09565622210502,
#   'y': 324.1385627746582},
#  {'height': 21.177000045776367,
#   'id': '2d3a3417',
#   'width': 293.62565656006336,
#   'x': 88.59965630471706,
#   'y': 391.5245624542236},
#  {'height': 24.23999834060669,
#   'id': 'b9b73e2d',
#   'width': 28.618218898773208,
#   'x': 88.44215623140335,
#   'y': 459.3230629920959},
#  {'height': 70.38600039482117,
#   'id': '1d8598b0',
#   'width': 176.67768716812128,
#   'x': 219.78206253647807,
#   'y': 438.32606277465817},
#  {'height': 10.368000268936157,
#   'id': '6626584d',
#   'width': 59.07956269383433,
#   'x': 88.77815628647804,
#   'y': 572.3960622310638},
#  {'height': 85.3439998626709,
#   'id': 'b56c4dd3',
#   'width': 154.48742477595806,
#   'x': 219.78206253647807,
#   'y': 534.920062637329},
#  {'height': 19.278000354766846,
#   'id': '5b1e8c5f',
#   'width': 95.66304990649223,
#   'x': 483.40828142166134,
#   'y': 679.5350624084472},
#  {'height': 19.080000400543213,
#   'id': '0fe1e2ea',
#   'width': 170.09962463378906,
#   'x': 921.2020313501357,
#   'y': 688.3190623283385},
#  {'height': 19.415998935699463,
#   'id': 'f3f5018d',
#   'width': 101.95996946096415,
#   'x': 449.3066248655319,
#   'y': 732.2450629234313},
#  {'height': 18.383999347686768,
#   'id': '258cb328',
#   'width': 182.5388440489769,
#   'x': 909.0123750329017,
#   'y': 732.581062889099},
#  {'height': 23.760000228881836,
#   'id': 'e1520e58',
#   'width': 31.991231024265304,
#   'x': 88.41815627217292,
#   'y': 945.7233744621276},
#  {'height': 20.567999839782715,
#   'id': '901afe33',
#   'width': 101.75934380292892,
#   'x': 220.5290624856949,
#   'y': 948.9873753547668},
#  {'height': 16.080000400543213,
#   'id': '97b21015',
#   'width': 46.043249666690855,
#   'x': 89.87015626430511,
#   'y': 1005.9033742904662},
#  {'height': 18.86400032043457,
#   'id': '6914f75d',
#   'width': 107.36587482690811,
#   'x': 221.45306257009508,
#   'y': 1009.8873744964599},
#  {'height': 27.666000366210938,
#   'id': 'ee7bc234',
#   'width': 38.630625486373916,
#   'x': 85.98215625286102,
#   'y': 1080.4186869621276},
#  {'height': 8.729999542236328,
#   'id': '613dc5df',
#   'width': 64.48181203007698,
#   'x': 140.43159363269808,
#   'y': 1089.2116876602172},
#  {'height': 38.1060004234314,
#   'id': '741ea084',
#   'width': 49.34671899676323,
#   'x': 923.7528749763965,
#   'y': 1072.6066866874694},
#  {'height': 27.648000240325928,
#   'id': '9c8738ba',
#   'width': 25.585218608379364,
#   'x': 993.7282500028609,
#   'y': 1080.4186869621276},
#  {'height': 51.75,
#   'id': '1e8f570a',
#   'width': 52.718906074762344,
#   'x': 1038.4107187449931,
#   'y': 1066.4596873283385},
#  {'height': 9.036784887313843,
#   'id': '90736736',
#   'width': 4.85965633392334,
#   'x': 85.82049379348754,
#   'y': 1173.4134377002715},
#  {'height': 79.43850231170654,
#   'id': 'c942ccba',
#   'width': 771.8890834646298,
#   'x': 137.66038516759875,
#   'y': 1134.950435256958},
#  {'height': 12.005859375,
#   'id': '05c98d73',
#   'width': 14.712890625,
#   'x': 944.4164062499999,
#   'y': 1171.273828125},
#  {'height': 11.290307521820068,
#   'id': '278cb0ed',
#   'width': 25.858218602836132,
#   'x': 999.3955311611294,
#   'y': 1171.1307183265685},
#  {'height': 13.130859375,
#   'id': 'b53d9c3f',
#   'width': 30.72509765625,
#   'x': 1059.688623046875,
#   'y': 1171.564599609375},
#  {'height': 11.72021484375,
#   'id': '9630486e',
#   'width': 82.2315673828125,
#   'x': 944.4749999999999,
#   'y': 1233.2396484375},
#  {'height': 8.19140625,
#   'id': '68862329',
#   'width': 21.7928466796875,
#   'x': 1070.20986328125,
#   'y': 1236.75087890625},
#  {'height': 15.732421875,
#   'id': 'db9d0c01',
#   'width': 165.8140869140625,
#   'x': 861.5999999999999,
#   'y': 1264.5873046875},
#  {'height': 8.37158203125,
#   'id': '4aaa9cf5',
#   'width': 19.7406005859375,
#   'x': 1072.6506591796874,
#   'y': 1269.73330078125},
#  {'height': 14.27783203125,
#   'id': '3663ea9f',
#   'width': 109.5794677734375,
#   'x': 917.2171874999999,
#   'y': 1299.04189453125},
#  {'height': 8.19140625,
#   'id': 'cc54fdbf',
#   'width': 21.6654052734375,
#   'x': 1070.6701904296874,
#   'y': 1302.75087890625},
#  {'height': 11.91796875,
#   'id': 'ce6039c2',
#   'width': 238.87646484375,
#   'x': 788.5376220703124,
#   'y': 1332.04189453125},
#  {'height': 8.19140625,
#   'id': '0c7d300b',
#   'width': 21.7928466796875,
#   'x': 1070.20986328125,
#   'y': 1335.75087890625},
#  {'height': 18.04833984375,
#   'id': '6a0b3171',
#   'width': 132.6925048828125,
#   'x': 894.5190673828124,
#   'y': 1362.40517578125},
#  {'height': 8.19140625,
#   'id': '2535eff4',
#   'width': 21.7203369140625,
#   'x': 1070.6701904296874,
#   'y': 1368.75087890625},
#  {'height': 16.02685546875,
#   'id': '8f10db67',
#   'width': 157.8017578125,
#   'x': 868.9048095703124,
#   'y': 1393.9330078125},
#  {'height': 8.02880859375,
#   'id': '5d1a5b58',
#   'width': 23.6484375,
#   'x': 1070.20986328125,
#   'y': 1401.9134765625}]

# %%
import json

json_data = []
for i in jsons_path:
  f = open(i)
  data = json.load(f)
  json_data.append(data)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-24-a72e592489d4> in <module>()
#       4 for i in jsons_path:
#       5   f = open(i)
# ----> 6   data = json.load(f)
#       7   json_data.append(data)
#
# /usr/lib/python3.7/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# /usr/lib/python3.7/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte

# %%
len(json_data)
# Out:
# 3000

# %%
len(json_data[0])
# Out:
# 34

# %%
json_data[0]
# Out:
# [{'parentId': 'cefabe1b',
#   'parentWord': 'ห้างหุ้นส่วน พรชนก แอร์ อิเลคทริค\nPhonchnk Ae Inekthnik Part., Ltd.',
#   'rect': {'height': 62.01604056358339,
#    'width': 284.93588829785585,
#    'x': 77.62612998336553,
#    'y': 106.20598754882813},
#   'style': {'fontFamily': 'TH_Charm_of_AU',
#    'fontSize': '16px',
#    'fontStyle': 'italic',
#    'fontVarient': 'normal',
#    'fontWeight': 'bold'},
#   'text': 'ห้างหุ้นส่วน พรชนก แอร์ อิเลคทริค\nPhonchnk Ae Inekthnik Part., Ltd.'},
#  {'parentId': '7bfac6b8',
#   'parentWord': '>ใบรับเงิน\ninvoice',
#   'rect': {'height': 15.328125,
#    'width': 82.93379463627934,
#    'x': 422.85148962065574,
#    'y': 106.33828125000001},
#   'style': {'fontFamily': 'FC_Knomphing_Regular',
#    'fontSize': '16px',
#    'fontStyle': 'normal',
#    'fontVarient': 'normal',
#    'fontWeight': 'bold'},
#   'text': '>ใบรับเงิน\ninvoice'},
#  {'parentId': 'a368ca3e',
#   'parentWord': 'ห้างหุ้นส่วน พรชนก แอร์ อิเลคทริค\nPhonchnk Ae Inekthnik Part., Ltd.',
#   'rect': {'height': 62.016040563583374,
#    'width': 284.93588829785585,
#    'x': 77.62612998336553,
#    'y': 654.116143798828},
#   'style': {'fontFamily': 'TH_Charm_of_AU',
#    'fontSize': '16px',
#    'fontStyle': 'italic',
#    'fontVarient': 'normal',
#    'fontWeight': 'bold'},
#   'text': 'ห้างหุ้นส่วน พรชนก แอร์ อิเลคทริค\nPhonchnk Ae Inekthnik Part., Ltd.'},
#  {'parentId': '4a016af7',
#   'parentWord': 'วันที่: 8 พฤศจิกายน 2563\nDate:',
#   'rect': {'height': 26.332746505737305,
#    'width': 266.3394280895591,
#    'x': 799.0937906563281,
#    'y': 652.3885665893554},
#   'style': {'fontFamily': 'fonttintin',
#    'fontSize': '16px',
#    'fontStyle': 'normal',
#    'fontVarient': 'normal',
#    'fontWeight': 'bold'},
#   'text': 'วันที่: 8 พฤศจิกายน 2563\nDate:'},
#  {'parentId': '738a6f5e',
#   'parentWord': 'เลขที่: 04277838\nINVOICE NO.: 04277838',
#   'rect': {'height': 53.40868091583252,
#    'width': 283.4853750541806,
#    'x': 791.2642499417066,
#    'y': 761.8885665893554},
#   'style': {'fontFamily': 'fonttintin',
#    'fontSize': '16px',
#    'fontStyle': 'normal',
#    'fontVarient': 'normal',
#    'fontWeight': 'bold'},
#   'text': 'เลขที่: 04277838\nINVOICE NO.: 04277838'},
#  {'parentId': 'd1f86449',
#   'parentWord': 'เลขประจำตัวผู้เสียภาษีอากร: 0 9049 82567 62 6\nTax id: 0 9049 82567 62 6',
#   'rect': {'height': 84.66943645477295,
#    'width': 324.27529978752136,
#    'x': 771.1955078601836,
#    'y': 901.3658758163451},
#   'style': {'fontFamily': 'fonttintin',
#    'fontSize': '16px',
#    'fontStyle': 'normal',
#    'fontVarient': 'normal',
#    'fontWeight': 'bold'},
#   'text': 'เลขประจำตัวผู้เสียภาษีอากร: 0 9049 82567 62 6\nTax id: 0 9049 82567 62 6'},
#  {'parentId': '71fd345a',
#   'parentWord': 'ห้างหุ้นส่วน พรชนก แอร์ อิเลคทริค\nPhonchnk Ae Inekthnik Part., Ltd.',
#   'rect': {'height': 19.9921875,
#    'width': 323.0579015985131,
#    'x': 81.20616090148687,
#    'y': 1059.28359375},
#   'style': {'fontFamily': 'FC_Knomphing_Regular',
#    'fontSize': '16px',
#    'fontStyle': 'normal',
#    'fontVarient': 'normal',
#    'fontWeight': 'bold'},
#   'text': 'ห้างหุ้นส่วน พรชนก แอร์ อิเลคทริค\nPhonchnk Ae Inekthnik Part., Ltd.'},
#  {'parentId': '8bfdc1e6',
#   'parentWord': 'เลขประจำตัวผู้เสียภาษีอากร: 0 9049 82567 62 6\nTax id: 0 9049 82567 62 6',
#   'rect': {'height': 38.0625,
#    'width': 329.86816406249994,
#    'x': 423.95742187499997,
#    'y': 1061.521875},
#   'style': {'fontFamily': 'TH_Mali_Grade6',
#    'fontSize': '16px',
#    'fontStyle': 'italic',
#    'fontVarient': 'normal',
#    'fontWeight': 'normal'},
#   'text': 'เลขประจำตัวผู้เสียภาษีอากร: 0 9049 82567 62 6\nTax id: 0 9049 82567 62 6'},
#  {'parentId': 'ff42451b',
#   'parentWord': 'เงื่อนไข:\nNote:\nเพนกวิน 849 875 สัตบุรุษ defendant 449',
#   'rect': {'height': 41.859375,
#    'width': 285.31640625,
#    'x': 790.9359374999999,
#    'y': 1057.725},
#   'style': {'fontFamily': 'TH_Mali_Grade6',
#    'fontSize': '16px',
#    'fontStyle': 'normal',
#    'fontVarient': 'normal',
#    'fontWeight': 'normal'},
#   'text': 'เงื่อนไข:\nNote:\nเพนกวิน 849 875 สัตบุรุษ defendant 449'},
#  {'parentId': '7c81150a',
#   'parentWord': '>ใบรับเงิน\ninvoice',
#   'rect': {'height': 15.9609375,
#    'width': 120.69140625,
#    'x': 768.5106445312499,
#    'y': 1292.586328125},
#   'style': {'fontFamily': 'Angsana_New',
#    'fontSize': '16px',
#    'fontStyle': 'italic',
#    'fontVarient': 'normal',
#    'fontWeight': 'normal'},
#   'text': '>ใบรับเงิน\ninvoice'},
#  {'parentId': 'eb637ee6',
#   'parentWord': 'ชื่อบริษัท: นาย กุลวดี โสวัฒนสกุล\nCUSTOMER NAME: Mr. kunwti sowatnskun',
#   'rect': {'height': 41.859375,
#    'width': 310.833984375,
#    'x': 78.89296875,
#    'y': 1379.13515625},
#   'style': {'fontFamily': 'TH_Mali_Grade6',
#    'fontSize': '16px',
#    'fontStyle': 'italic',
#    'fontVarient': 'normal',
#    'fontWeight': 'normal'},
#   'text': 'ชื่อบริษัท: นาย กุลวดี โสวัฒนสกุล\nCUSTOMER NAME: Mr. kunwti sowatnskun'},
#  {'parentId': '5627329d',
#   'parentWord': 'เว็บไซต์: www.Martha.biz\nWebsite: www.Martha.biz',
#   'rect': {'height': 39.66796875,
#    'width': 231.65332031250003,
#    'x': 78.781640625,
#    'y': 1501.3734375},
#   'style': {'fontFamily': 'TH_Mali_Grade6',
#    'fontSize': '16px',
#    'fontStyle': 'italic',
#    'fontVarient': 'normal',
#    'fontWeight': 'normal'},
#   'text': 'เว็บไซต์: www.Martha.biz\nWebsite: www.Martha.biz'},
#  {'parentId': '25d34883',
#   'parentWord': 'อีเมลล์: Stromberg@mail.net\nemail: Stromberg@mail.net',
#   'rect': {'height': 41.71875,
#    'width': 232.92773437500003,
#    'x': 78.9955078125,
#    'y': 1622.6390625000001},
#   'style': {'fontFamily': 'TH_Mali_Grade6',
#    'fontSize': '16px',
#    'fontStyle': 'italic',
#    'fontVarient': 'normal',
#    'fontWeight': 'normal'},
#   'text': 'อีเมลล์: Stromberg@mail.net\nemail: Stromberg@mail.net'},
#  {'parentId': 'b4bfa048',
#   'parentWord': 'วันที่: 8 พฤศจิกายน 2563\nDate:',
#   'rect': {'height': 22.6171875,
#    'width': 221.53417968749994,
#    'x': 478.76015624999997,
#    'y': 1379.13515625},
#   'style': {'fontFamily': 'TH_Mali_Grade6',
#    'fontSize': '16px',
#    'fontStyle': 'italic',
#    'fontVarient': 'normal',
#    'fontWeight': 'normal'},
#   'text': 'วันที่: 8 พฤศจิกายน 2563\nDate:'},
#  {'parentId': 'f79dcc9f',
#   'parentWord': 'เลขประจำตัวผู้เสียภาษีอากร: 0 9049 82567 62 6\nTax id: 0 9049 82567 62 6',
#   'rect': {'height': 38.0625,
#    'width': 329.86816406249994,
#    'x': 424.44960937499997,
#    'y': 1478.93203125},
#   'style': {'fontFamily': 'TH_Mali_Grade6',
#    'fontSize': '16px',
#    'fontStyle': 'italic',
#    'fontVarient': 'normal',
#    'fontWeight': 'normal'},
#   'text': 'เลขประจำตัวผู้เสียภาษีอากร: 0 9049 82567 62 6\nTax id: 0 9049 82567 62 6'},
#  {'parentId': 'df6294ad',
#   'parentWord': 'โทรศัพท์: +66 2164 6136\nMobile phone: +66 2164 6136',
#   'rect': {'height': 43.330078125,
#    'width': 307.5205078125,
#    'x': 793.2679687499999,
#    'y': 1384.5140625},
#   'style': {'fontFamily': 'Cordia_New',
#    'fontSize': '16px',
#    'fontStyle': 'italic',
#    'fontVarient': 'normal',
#    'fontWeight': 'normal'},
#   'text': 'โทรศัพท์: +66 2164 6136\nMobile phone: +66 2164 6136'},
#  {'parentId': '3bd39a71',
#   'parentWord': 'เว็บไซต์: www.Martha.biz\nWebsite: www.Martha.biz',
#   'rect': {'height': 44.34960937500023,
#    'width': 236.6162109375,
#    'x': 863.4486328124999,
#    'y': 1514.7328125},
#   'style': {'fontFamily': 'Cordia_New',
#    'fontSize': '16px',
#    'fontStyle': 'italic',
#    'fontVarient': 'normal',
#    'fontWeight': 'normal'},
#   'text': 'เว็บไซต์: www.Martha.biz\nWebsite: www.Martha.biz'},
#  {'parentId': '61a5b53c',
#   'parentWord': 'โทรสาร: 0 4172 4074\nfax: 0 4172 4074',
#   'rect': {'height': 15.580078125,
#    'width': 265.34033203125,
#    'x': 834.1078124999999,
#    'y': 1647.0140625000001},
#   'style': {'fontFamily': 'Cordia_New',
#    'fontSize': '16px',
#    'fontStyle': 'italic',
#    'fontVarient': 'normal',
#    'fontWeight': 'normal'},
#   'text': 'โทรสาร: 0 4172 4074\nfax: 0 4172 4074'},
#  {'parentId': '72cef884',
#   'parentWord': 'เลขประจำตัวผู้เสียภาษีอากร: 0 9049 82567 62 6\nTax id: 0 9049 82567 62 6',
#   'rect': {'height': 37.78125,
#    'width': 326.55468785762787,
#    'x': 81.13125,
#    'y': 1734.4242187500001},
#   'style': {'fontFamily': 'FC_Knomphing_Regular',
#    'fontSize': '16px',
#    'fontStyle': 'normal',
#    'fontVarient': 'normal',
#    'fontWeight': 'bold'},
#   'text': 'เลขประจำตัวผู้เสียภาษีอากร: 0 9049 82567 62 6\nTax id: 0 9049 82567 62 6'},
#  {'parentId': '3093e496',
#   'parentWord': 'ผู้จัดทำ:\nsign by:\n',
#   'rect': {'height': 28.67999839782715,
#    'width': 136.02768757939333,
#    'x': 424.41393742561337,
#    'y': 1731.8670936584474},
#   'style': {'fontFamily': 'fonttintin',
#    'fontSize': '16px',
#    'fontStyle': 'italic',
#    'fontVarient': 'normal',
#    'fontWeight': 'normal'},
#   'text': 'ผู้จัดทำ:\nsign by:\n'},
#  {'parentId': 'ca2b49e3',
#   'parentWord': '1',
#   'rect': {'height': 9.050999879837036,
#    'width': 2.7720000743865967,
#    'x': 84.0351562410593,
#    'y': 392.04900012016293},
#   'style': {'fontFamily': 'TH_Chakra_Petch',
#    'fontSize': '14px',
#    'fontStyle': 'normal',
#    'fontVarient': 'normal',
#    'fontWeight': 'normal'},
#   'text': '1'},
#  {'parentId': '246ea10a',
#   'parentWord': '129 กรมพัฒนาที่ดิน rainstorm เพิ่มปริมาณ 363 318\n',
#   'rect': {'height': 17.5958890914917,
#    'width': 300.88842907547945,
#    'x': 119.87299547195435,
#    'y': 384.53587446212765},
#   'style': {'fontFamily': 'TH_Sarabun',
#    'fontSize': '14px',
#    'fontStyle': 'italic',
#    'fontVarient': 'normal',
#    'fontWeight': 'bold'},
#   'text': '129 กรมพัฒนาที่ดิน rainstorm เพิ่มปริมาณ 363 318\n'},
#  {'parentId': 'c8b80e60',
#   'parentWord': '620,342.20',
#   'rect': {'height': 26.66400218009943,
#    'width': 155.67374995350838,
#    'x': 936.8631562650203,
#    'y': 382.4159980773926},
#   'style': {'fontFamily': 'fonttintin',
#    'fontSize': '22px',
#    'fontStyle': 'normal',
#    'fontVarient': 'normal',
#    'fontWeight': 'normal'},
#   'text': '620,342.20'},
#  {'parentId': 'dbe63193',
#   'parentWord': '2',
#   'rect': {'height': 9.050999879837036,
#    'width': 6.363000154495239,
#    'x': 84.20315626859664,
#    'y': 445.29900012016293},
#   'style': {'fontFamily': 'TH_Chakra_Petch',
#    'fontSize': '14px',
#    'fontStyle': 'normal',
#    'fontVarient': 'normal',
#    'fontWeight': 'normal'},
#   'text': '2'},
#  {'parentId': 'f049505a',
#   'parentWord': '531 negate แมลงจิ้มฟันจระเข้ 422 เหนื่อยหอบ\n',
#   'rect': {'height': 21.509252786636353,
#    'width': 271.7763770967722,
#    'x': 118.49204607903958,
#    'y': 436.8408728599548},
#   'style': {'fontFamily': 'TH_Sarabun',
#    'fontSize': '14px',
#    'fontStyle': 'italic',
#    'fontVarient': 'normal',
#    'fontWeight': 'bold'},
#   'text': '531 negate แมลงจิ้มฟันจระเข้ 422 เหนื่อยหอบ\n'},
#  {'parentId': 'd2f509d3',
#   'parentWord': '1,054.30',
#   'rect': {'height': 26.532000303268433,
#    'width': 119.92781245708466,
#    'x': 972.609093761444,
#    'y': 435.7979999542236},
#   'style': {'fontFamily': 'fonttintin',
#    'fontSize': '22px',
#    'fontStyle': 'normal',
#    'fontVarient': 'normal',
#    'fontWeight': 'normal'},
#   'text': '1,054.30'},
#  {'parentId': '5412a3d6',
#   'parentWord': '3',
#   'rect': {'height': 9.050999879837036,
#    'width': 6.341999530792236,
#    'x': 84.18215627074241,
#    'y': 498.54900012016293},
#   'style': {'fontFamily': 'TH_Chakra_Petch',
#    'fontSize': '14px',
#    'fontStyle': 'normal',
#    'fontVarient': 'normal',
#    'fontWeight': 'normal'},
#   'text': '3'},
#  {'parentId': '7d37fd29',
#   'parentWord': 'sawfish 990 นับถือ riflemen ส้มเขียวหวาน\n',
#   'rect': {'height': 14.676888942718506,
#    'width': 249.78230313956738,
#    'x': 118.49780755341054,
#    'y': 493.95487461090084},
#   'style': {'fontFamily': 'TH_Sarabun',
#    'fontSize': '14px',
#    'fontStyle': 'italic',
#    'fontVarient': 'normal',
#    'fontWeight': 'bold'},
#   'text': 'sawfish 990 นับถือ riflemen ส้มเขียวหวาน\n'},
#  {'parentId': '2365c60',
#   'parentWord': '3.66',
#   'rect': {'height': 25.046999931335392,
#    'width': 51.62756225466728,
#    'x': 1041.109312748909,
#    'y': 489.0479999542236},
#   'style': {'fontFamily': 'fonttintin',
#    'fontSize': '22px',
#    'fontStyle': 'normal',
#    'fontVarient': 'normal',
#    'fontWeight': 'normal'},
#   'text': '3.66'},
#  {'parentId': 'c3effb75',
#   'parentWord': '4',
#   'rect': {'height': 9.050999879837036,
#    'width': 6.341999530792236,
#    'x': 84.18215627074241,
#    'y': 551.7990001201629},
#   'style': {'fontFamily': 'TH_Chakra_Petch',
#    'fontSize': '14px',
#    'fontStyle': 'normal',
#    'fontVarient': 'normal',
#    'fontWeight': 'normal'},
#   'text': '4'},
#  {'parentId': '735bb852',
#   'parentWord': 'โคมตาวัว hasty Corp 977 Abraham\n',
#   'rect': {'height': 17.8342502117157,
#    'width': 211.2468921840191,
#    'x': 119.88269451856614,
#    'y': 547.225874519348},
#   'style': {'fontFamily': 'TH_Sarabun',
#    'fontSize': '14px',
#    'fontStyle': 'italic',
#    'fontVarient': 'normal',
#    'fontWeight': 'bold'},
#   'text': 'โคมตาวัว hasty Corp 977 Abraham\n'},
#  {'parentId': 'a0ca254e',
#   'parentWord': '3,615,127.68',
#   'rect': {'height': 26.664002180099487,
#    'width': 152.31074957549572,
#    'x': 939.3319689989089,
#    'y': 542.1659980773925},
#   'style': {'fontFamily': 'fonttintin',
#    'fontSize': '22px',
#    'fontStyle': 'normal',
#    'fontVarient': 'normal',
#    'fontWeight': 'normal'},
#   'text': '3,615,127.68'},
#  {'parentId': '7b8d55c9',
#   'parentWord': 'รวมเงิน\nSub total',
#   'rect': {'height': 10.134000778198242,
#    'width': 87.97500009834766,
#    'x': 662.6432812571525,
#    'y': 591.9659992218017},
#   'style': {'fontFamily': 'TH_Chakra_Petch',
#    'fontSize': '12px',
#    'fontStyle': 'italic',
#    'fontVarient': 'normal',
#    'fontWeight': 'normal'},
#   'text': 'รวมเงิน\nSub total'},
#  {'parentId': '3f676bd4',
#   'parentWord': '4,236,527.84',
#   'rect': {'height': 8.729999899864197,
#    'width': 65.4618752002716,
#    'x': 1027.7812500357627,
#    'y': 594.3420001029967},
#   'style': {'fontFamily': 'TH_Chakra_Petch',
#    'fontSize': '12px',
#    'fontStyle': 'italic',
#    'fontVarient': 'normal',
#    'fontWeight': 'normal'},
#   'text': '4,236,527.84'}]

# %% [markdown]
# # create folders to put all the files in

# %%
os.mkdir("/content/outputs")
os.mkdir("/content/outputs/set1")

# %%
len(json_data[0])
# Out:
# 34

# %%
import os
 
dir = '/content/outputs/set1/1'
for f in os.listdir(dir):
    os.remove(os.path.join(dir, f))

# %%
from PIL import Image


count = 0

# for i in range(len(json_data)):
for i in range(len(json_data)):
  save_path = "/content/outputs/set1"
  try:
    os.mkdir(save_path + "/{}".format(lst_dir_set1[i]))
  except:
    print("")

  for j in range(len(json_data[i])):
    # read image elements in one image
    img = cv2.imread(images_path[i])
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # specify cropped area
    x1 = round(json_data[i][j]['rect']['x'])
    x2 = round(x1 + json_data[i][j]['rect']['width'])
    y1 = round(json_data[i][j]['rect']['y'])
    y2 = round(y1 + json_data[i][j]['rect']['height'])
    print('original {}'.format(img.shape) + " (x1,y1,x2,y2) = {}, {}, {}, {}".format(x1, y1, x2, y2))
    img = img[y1:y2,x1:x2]
    print(img.shape)

    filename = save_path + "/{}".format(lst_dir_set1[i]) + "/image_{}_element_{}.png".format(i, count)
    # save image from numpy array
    try:
      cv2.imwrite(filename, img)
    except:
      print('', end='')
    # im.save(save_path + "/image_{}_element_{}.png".format(i, count))
    count = count + 1
# Out:
# Streaming output truncated to the last 5000 lines.
# original (1531, 1191, 3) (x1,y1,x2,y2) = 778, 630, 790, 639
# (9, 12, 3)
# original (1531, 1191, 3) (x1,y1,x2,y2) =
 3)
# original (1684, 1191, 3) (x1,y1,x2,y2) = 443, 1219, 736, 1263
# (44, 293, 3)
# original (1684, 1191, 3) (x1,y1,x2,y2) = 425, 1345, 751, 1448
# (103, 326, 3)
# original (1684, 1191, 3) (x1,y1,x2,y2) = 835, 733, 1098, 749
# (16, 263, 3)
# original (1684, 1191, 3) (x1,y1,x2,y2) = 850, 835, 1098, 882
# (47, 248, 3)
# original (1684, 1191, 3) (x1,y1,x2,y2) = 776, 966, 1098, 1014
# (48, 322, 3)
# original (1684, 1191, 3) (x1,y1,x2,y2) = 770, 1093, 1100, 1199
# (106, 330, 3)
# original (1684, 1191, 3) (x1,y1,x2,y2) = 774, 1285, 1098, 1328
# (43, 324, 3)
# original (1684, 1191, 3) (x1,y1,x2,y2) = 78, 1516, 343, 1559
# (43, 265, 3)
# original (1684, 1191, 3) (x1,y1,x2,y2) = 79, 1636, 278, 1655
# (19, 199, 3)
# original (1684, 1191, 3) (x1,y1,x2,y2) = 423, 1516, 698, 1563
# (47, 275, 3)
# original (1684, 1191, 3) (x1,y1,x2,y2) = 105, 1727, 410, 1773
# (0, 305, 3)
# original (1684, 1191, 3) (x1,y1,x2,y2) = 157, 1860, 410, 1878
# (0, 253, 3)
# original (1684, 1191, 3) (x1,y1,x2,y2) = 78, 1963, 409, 2071
# (0, 331, 3)
# original (1684, 1191, 3) (x1,y1,x2,y2) = 97, 2156, 408, 2205
# (0, 311, 3)
# original (1684, 1191, 3) (x1,y1,x2,y2) = 423, 1723, 734, 1740
# (0, 311, 3)
# original (1684, 1191, 3) (x1,y1,x2,y2) = 511, 2273, 664, 2306
# (0, 153, 3)
# original (1684, 1191, 3) (x1,y1,x2,y2) = 83, 101, 187, 116
# (15, 104, 3)
# original (1684, 1191, 3) (x1,y1,x2,y2) = 877, 101, 962, 114
# (13, 85, 3)
# original (1684, 1191, 3) (x1,y1,x2,y2) = 994, 85, 1076, 127
# (42, 82, 3)
# original (1684, 1191, 3) (x1,y1,x2,y2) = 82, 150, 850, 208
# (58, 768, 3)
# original (1684, 1191, 3) (x1,y1,x2,y2) = 916, 152, 988, 171
# (19, 72, 3)
# original (1684, 1191, 3) (x1,y1,x2,y2) = 1065, 161, 1096, 171
# (10, 31, 3)
# original (1684, 1191, 3) (x1,y1,x2,y2) = 82, 220, 869, 343
# (123, 787, 3)
# original (1684, 1191, 3) (x1,y1,x2,y2) = 877, 226, 990, 245
# (19, 113, 3)
# original (1684, 1191, 3) (x1,y1,x2,y2) = 1049, 235, 1096, 245
# (10, 47, 3)
# original (1684, 1191, 3) (x1,y1,x2,y2) = 83, 361, 861, 418
# (57, 778, 3)
# original (1684, 1191, 3) (x1,y1,x2,y2) = 943, 362, 991, 381
# (19, 48, 3)
# original (1684, 1191, 3) (x1,y1,x2,y2) = 1075, 371, 1096, 380
# (9, 21, 3)
# original (1684, 1191, 3) (x1,y1,x2,y2) = 868, 430, 988, 445
# (15, 120, 3)
# original (1684, 1191, 3) (x1,y1,x2,y2) = 1005, 433, 1093, 447
# (14, 88, 3)
# original (1684, 1191, 3) (x1,y1,x2,y2) = 758, 461, 987, 482
# (21, 229, 3)
# original (1684, 1191, 3) (x1,y1,x2,y2) = 1066, 466, 1093, 478
# (12, 27, 3)
# original (1684, 1191, 3) (x1,y1,x2,y2) = 652, 495, 987, 510
# (15, 335, 3)
# original (1684, 1191, 3) (x1,y1,x2,y2) = 1005, 499, 1093, 513
# (14, 88, 3)

# %%
len(os.listdir('/content/outputs/set1'))
# Out:
# 3001

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import os
import shutil
from shutil import make_archive

def make_archive(source, destination, format='zip'):
    import os
    import shutil
    from shutil import make_archive
    base, name = os.path.split(destination)
    archive_from = os.path.dirname(source)
    archive_to = os.path.basename(source.strip(os.sep))
    print(f'Source: {source}\nDestination: {destination}\nArchive From: {archive_from}\nArchive To: {archive_to}\n')
    shutil.make_archive(name, format, archive_from, archive_to)
    shutil.move('%s.%s' % (name, format), destination)

make_archive('/content/outputs/set1', '/content/outputs/set1')
# Out:
# Source: /content/outputs/set1
# Destination: /content/outputs/set1
# Archive From: /content/outputs
# Archive To: set1

# %%
import shutil
shutil.make_archive('/content/gdrive/MyDrive', 'zip', '/content/outputs/set1')

# %%
jsons_path[:5]
# Out:
# ['/content/train/set1/1/gt_text.json',
#  '/content/train/set1/10/gt_text.json',
#  '/content/train/set1/100/gt_text.json',
#  '/content/train/set1/1000/gt_text.json',
#  '/content/train/set1/1001/gt_text.json']

# %%
json_data[0][0]
# Out:
# {'parentId': 'cefabe1b',
#  'parentWord': 'ห้างหุ้นส่วน พรชนก แอร์ อิเลคทริค\nPhonchnk Ae Inekthnik Part., Ltd.',
#  'rect': {'height': 62.01604056358339,
#   'width': 284.93588829785585,
#   'x': 77.62612998336553,
#   'y': 106.20598754882813},
#  'style': {'fontFamily': 'TH_Charm_of_AU',
#   'fontSize': '16px',
#   'fontStyle': 'italic',
#   'fontVarient': 'normal',
#   'fontWeight': 'bold'},
#  'text': 'ห้างหุ้นส่วน พรชนก แอร์ อิเลคทริค\nPhonchnk Ae Inekthnik Part., Ltd.'}
